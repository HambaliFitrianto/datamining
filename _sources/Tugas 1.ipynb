# %% [markdown]
# # TUGAS 1

# %%
import pandas as pd
import numpy as np
import math

# %%
dataset_url="https://raw.githubusercontent.com/HambaliFitrianto/datamining/main/data-kejadian-bencana-banjir-di-provinsi-dki-jakarta-tahun-2017-bulan-desember.csv"
p=pd.read_csv(dataset_url, index_col=0)

# %%
p
# Out:
#                                   kecamatan        kelurahan  \
# kota_administrasi
# Jakarta Barat                     KALIDERES            KAMAL
# Jakarta Barat             GROGOL PETAMBURAN    JELAMBAR BARU
# Jakarta Selatan                PASAR MINGGU      JATI PADANG
# Jakarta Selatan                    PANCORAN         KALIBATA
# Jakarta Selatan                   SETIABUDI   KUNINGAN TIMUR
# Jakarta Selatan                       TEBET       KEBON BARU
# Jakarta Selatan                       TEBET       BUKIT DURI
# Jakarta Selatan                       TEBET        MANGGARAI
# Jakarta Selatan                   JAGAKARSA        JAGAKARSA
# Jakarta Selatan                    CILANDAK      PONDOK LABU
# Jakarta Timur                       MAKASAR  CIPINANG MELAYU
# Jakarta Timur                    JATINEGARA   CIPINANG MUARA
# Jakarta Timur                        CAKUNG      RAWA TERATE
# Jakarta Timur                    PASAR REBO         KALISARI
# ...

# %%
def diss(x,y):
  a = 4
  b = 0
  for col in ["kecamatan", "kelurahan", "rw", "jumlah_terdampak_rw", "jumlah_terdampak_rt",	"jumlah_terdampak_kk", "jumlah_terdampak_jiwa",	"ketinggian_air",	"tanggal_kejadian",	"lama_genangan",	"jumlah_meninggal", "jumlah_hilang",	"jumlah_luka_berat",	"jumlah_luka_ringan",	"jumlah_pengungsi_tertinggi",	"jumlah_tempat_pengungsian",	"nilai_kerugian", "kota_administrasi"	]:
    if p[col][x] == p[col][y]:
      b+=1
    return (a-b)/a

# %%
print(diss(1,1))
# Out:
# 0.75

# %%
p.describe()
# Out:
#        jumlah_terdampak_rw  jumlah_terdampak_rt  jumlah_terdampak_kk  \
# count            26.000000            26.000000            26.000000
# mean              1.961538             2.730769             5.038462
# std               1.280024             2.324783            24.110547
# min               1.000000             1.000000             0.000000
# 25%               1.000000             1.000000             0.000000
# 50%               1.500000             2.000000             0.000000
# 75%               2.750000             3.750000             0.000000
# max               6.000000            11.000000           123.000000
#
#        jumlah_terdampak_jiwa  lama_genangan  jumlah_meninggal  jumlah_hilang  \
# count              26.000000           26.0              26.0           26.0
# mean               15.538462            0.0               0.0            0.0
# std                72.417805            0.0               0.0            0.0
# ...

# %%
#normalisasi jumlah_terdampak_rw
std_jtw = 1.280024
mean_jtw = 1.961538
for col1 in ["jumlah_terdampak_rw"]:
    p1 = p[col1]
    hasil1 = (p1-mean_jtw)/std_jtw
    print(hasil1)

#normalisasi jumlah_terdampak_rt
std_jtr = 2.324783	
mean_jtr = 3.366667
for col2 in ["jumlah_terdampak_rt"]:
    p2 = p[col2]
    hasil2 = (p2-mean_jtr)/std_jtr
    print(hasil2)
# Out:
# kota_administrasi
# Jakarta Barat       0.030048
# Jakarta Barat       0.811283
# Jakarta Selatan    -0.751187
# Jakarta Selatan     0.811283
# Jakarta Selatan    -0.751187
# Jakarta Selatan    -0.751187
# Jakarta Selatan     0.811283
# Jakarta Selatan    -0.751187
# Jakarta Selatan    -0.751187
# Jakarta Selatan    -0.751187
# Jakarta Timur       0.030048
# Jakarta Timur      -0.751187
# Jakarta Timur      -0.751187
# Jakarta Timur       0.030048
# Jakarta Timur      -0.751187
# Jakarta Utara      -0.751187
# Jakarta Utara       0.030048
# Jakarta Utara       1.592519
# Jakarta Utara       1.592519
# Jakarta Utara      -0.751187
# Jakarta Utara       3.154989
# Jakarta Utara       0.030048
# Jakarta Utara      -0.751187
# Jakarta Utara       0.811283
# Jakarta Utara      -0.751187
# Kepulauan Seribu    0.030048
# Name: jumlah_terdampak_rw, dtype: float64
# kota_administrasi
# Jakarta Barat       1.132722
# Jakarta Barat      -0.587869
# Jakarta Selatan    -1.018016
# ...

# %%
# Menghitung jarak data Numeric dengan cara Euclidean
def num_p(a,b,c):
    result = 0
    for col in [hasil1, hasil2]:
        result = math.pow(abs(col[a] - col[b]), c)
    return result**(1/c)

# %%
print(num_p(1,2,2))
print(num_p(1,3,2))
print(num_p(1,4,2))
# Out:
# 0.4301476739979603
# 0.4301476739979603
# 0.4301476739979603

# %% [markdown]
# **SIMILARITY**

# %%
print("Jarak d(1,2) =", diss(1,2)+num_p(1,2,2))
# Out:
# Jarak d(1,2) = 1.4301476739979604

# %%
print("Jarak d(1,2) =", diss(1,3)+num_p(1,3,3))
# Out:
# Jarak d(1,2) = 1.4301476739979604

# %%
print("Jarak d(1,2) =", diss(1,4)+num_p(1,4,4))
# Out:
# Jarak d(1,2) = 1.4301476739979604
